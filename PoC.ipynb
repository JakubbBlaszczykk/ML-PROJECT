# %%
#%pip install pyarrow

import os
from dotenv import load_dotenv
import polars as pl
import joblib

# %%
load_dotenv("config/.env")
DATA_CLEANED = os.getenv("URL_CLEANED_DATA")

print(f"Loading cleaned data from: {DATA_CLEANED}")
df = pl.read_parquet(DATA_CLEANED).to_pandas()
print("Data loaded successfully.")
# Out:
# Loading cleaned data from: https://huggingface.co/datasets/wojciechjurewicz/imdb/resolve/main/imdb_us_movies_cleaned.parquet
# Data loaded successfully.

# %%
df.shape
# Out:
# (390855, 11)

# %%
df.sample(5)
# Out:
#         num__isAdult  num__startYear  num__runtimeMinutes  num__averageRating  \
# 310005           0.0          2025.0                 93.0                -1.0
# 307808           0.0          2022.0                 76.0                -1.0
# 256006           0.0            -1.0                 -1.0                -1.0
# 95944            0.0          1934.0                 71.0                 5.6
# 291145           0.0            -1.0                 -1.0                -1.0
#
#         num__numVotes           cat__title   cat__types          cat__genres  \
# 310005           -1.0  The Broke Challenge      missing            animation
# 307808           -1.0      Chaotic Justice  imdbdisplay         action,drama
# 256006           -1.0     Forbidden Mystic      missing              mystery
# 95944            72.0  Port of Lost Dreams  imdbdisplay  crime,drama,romance
# 291145           -1.0                Fore!      missing               comedy
#
#                                           remainder__cast  \
# 310005  [{'category': 'actor', 'job': 'missing', 'char...
# 307808  [{'category': 'actor', 'job': 'missing', 'char...
# 256006  [{'category': 'writer', 'job': 'writer', 'char...
# 95944   [{'category': 'cinematographer', 'job': 'missi...
# 291145  [{'category': 'producer', 'job': 'producer', '...
#
#                                      remainder__directors  \
# 310005  [{'primaryName': 'E.G. Thompson', 'birthYear':...
# 307808  [{'primaryName': 'Hsin-che Cheng', 'birthYear'...
# 256006                                                 []
# 95944   [{'primaryName': 'Frank R. Strayer', 'birthYea...
# 291145                                                 []
#
#                                        remainder__writers
# 310005  [{'primaryName': 'E.G. Thompson', 'birthYear':...
# 307808  [{'primaryName': 'Hsin-che Cheng', 'birthYear'...
# 256006  [{'primaryName': 'J.R. Russell', 'birthYear': ...
# 95944   [{'primaryName': 'Robert Ellis', 'birthYear': ...
# 291145                                                 []

# %%
PREPROCESSOR_FILE = 'preprocessor.joblib'
TFIDF_VECTORIZER_FILE = 'tfidf_vectorizer.joblib'

FULL_PREPROCESSOR = joblib.load(PREPROCESSOR_FILE)
TFIDF_VECTORIZER = joblib.load(TFIDF_VECTORIZER_FILE)

print("Preprocessor and TF-IDF Vectorizer loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 PREPROCESSOR_FILE = 'preprocessor.joblib'
#       2 TFIDF_VECTORIZER_FILE = 'tfidf_vectorizer.joblib'
# ----> 4 FULL_PREPROCESSOR = joblib.load(PREPROCESSOR_FILE)
#       5 TFIDF_VECTORIZER = joblib.load(TFIDF_VECTORIZER_FILE)
#       7 print("Preprocessor and TF-IDF Vectorizer loaded successfully.")
#
# File c:\Users\jakub\ML-PROJECT\.venv\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File c:\Users\jakub\ML-PROJECT\.venv\Lib\site-packages\joblib\numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1205, in _Unpickler.load(self)
#    1203             raise EOFError
#    1204         assert isinstance(key, bytes_types)
# -> 1205         dispatch[key[0]](self)
#    1206 except _Stop as stopinst:
#    1207     return stopinst.value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1530, in _Unpickler.load_stack_global(self)
#    1528 if type(name) is not str or type(module) is not str:
#    1529     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1530 self.append(self.find_class(module, name))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1574, in _Unpickler.find_class(self, module, name)
#    1572 __import__(module, level=0)
#    1573 if self.proto >= 4:
# -> 1574     return _getattribute(sys.modules[module], name)[0]
#    1575 else:
#    1576     return getattr(sys.modules[module], name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:325, in _getattribute(obj, name)
#     323         obj = getattr(obj, subpath)
#     324     except AttributeError:
# --> 325         raise AttributeError("Can't get attribute {!r} on {!r}"
#     326                              .format(name, obj)) from None
#     327 return obj, parent
#
# AttributeError: Can't get attribute 'SearchCorpusGenerator' on <module '__main__'>
